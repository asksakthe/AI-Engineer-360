# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from HA_VisualClass import CovidVisualization
# Out:
# Dataframes df are created Successfully
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 from HA_VisualClass import CovidVisualization
#
# File ~/Documents/AI/Training_2025/AI-Engineer-360/HomeAssignments/week05Day10/HA_VisualClass.py:1
# ----> 1 from HA_BaseClass import Data_Pro
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# File ~/Documents/AI/Training_2025/AI-Engineer-360/HomeAssignments/week05Day10/HA_BaseClass.py:25
#      21         except Exception as e:
#      22             print("Dataset is not available in the path, Check and proceed")
# ---> 25 proc = Data_Pro('country_wise_latest.csv')
#
# TypeError: __init__() should return None, not 'DataFrame'

# %%
obj_viz = CovidVisualization('country_wise_latest.csv')
obj_viz.view_Barchart('Country/Region','Confirmed','Covid Confirmed Cases by Country','Country/Region','Confirmed Cases')
# Out:
# Dataframes df are created Successfully
