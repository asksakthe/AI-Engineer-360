# %%
import pandas as pd

df = pd.read_csv('country_wise_latest.csv')
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
def count_ByRegionwise(dataFrame):
    grp = dataFrame.groupby('Country/Region')[['Confirmed', 'Deaths', 'Recovered']]
    return grp.sum()


print(count_ByRegionwise(df))
# Out:
#                     Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan             36263    1269      25198
# Albania                  4880     144       2745
# Algeria                 27973    1163      18837
# Andorra                   907      52        803
# Angola                    950      41        242
# ...                       ...     ...        ...
# West Bank and Gaza      10621      78       3752
# Western Sahara             10       1          8
# Yemen                    1691     483        833
# Zambia                   4552     140       2815
# Zimbabwe                 2704      36        542
#
# [187 rows x 3 columns]

# %%
#method to return the confirmed cases which is not more than 10
def FilterOutput(target_Col):
    df_Filtered = df_Filtered[df[target_Col]> 10]
    return df_Filtered

inp = 'Confirmed'
df[df['Confirmed']> 10]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#Identify Region with Highest Confirmed Cases
dataF = df.sort_values(by='Confirmed', ascending=False)
dataF.head(1)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
#Sort Data by Confirmed Cases
# Save sorted dataset into a new CSV file.
dataF.to_csv('Sorted_Confirmed.csv')

# %%
#Top 5 Countries by Case Count
dataF.head()
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
# 23          Brazil    2442375   87618    1846641   508116      23284
# 79           India    1480073   33408     951166   495499      44457
# 138         Russia     816680   13334     602249   201097       5607
# 154   South Africa     452529    7067     274925   170537       7096
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 79          637          33598                2.26                  64.26
# 138          85           3077                1.63                  73.74
# 154         298           9848                1.56                  60.75
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
#Region with Lowest Death Count
df_AscenDeath = df.sort_values(by='Deaths',ascending=True)
df_AscenDeath.head(1)
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 30       Cambodia        226       0        147      79          1
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 30           0              4                 0.0                  65.04
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 30                     0.0                  171             55
#
#     1 week % increase       WHO Region
# 30              32.16  Western Pacific

# %%
#India’s Case Summary (as of April 29, 2020)
df.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
#Calculate Mortality Rate by Region
#o Death-to-confirmed case ratio.
dataF['D2C_Ratio'] = (dataF['Deaths'] / dataF['Confirmed']) * 100
rat = dataF.groupby('Country/Region')[['D2C_Ratio']]
print(rat.sum())
# Out:
#                     D2C_Ratio
# Country/Region
# Afghanistan          3.499435
# Albania              2.950820
# Algeria              4.157581
# Andorra              5.733186
# Angola               4.315789
# ...                       ...
# West Bank and Gaza   0.734394
# Western Sahara      10.000000
# Yemen               28.562980
# Zambia               3.075571
# Zimbabwe             1.331361
#
# [187 rows x 1 columns]

# %%
#Compare Recovery Rates Across Regions
dataF['RecoveryRate'] = (dataF['Recovered']/dataF['Confirmed'])*100
dataRecove = dataF.groupby('Country/Region')[['RecoveryRate']]
print(dataRecove.sum())
# Out:
#                     RecoveryRate
# Country/Region
# Afghanistan            69.486805
# Albania                56.250000
# Algeria                67.339935
# Andorra                88.533627
# Angola                 25.473684
# ...                          ...
# West Bank and Gaza     35.326240
# Western Sahara         80.000000
# Yemen                  49.260792
# Zambia                 61.840949
# Zimbabwe               20.044379
#
# [187 rows x 1 columns]

# %%
dataF.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region', 'D2C_Ratio', 'RecoveryRate'],
#       dtype='object')

# %%
#Identify Regions with Zero Recovered Cases
import os
data_recover = dataF['Recovered'] == 0
data_recover
# Out:
# 173    False
# 23     False
# 79     False
# 138    False
# 154    False
#        ...
# 49     False
# 140    False
# 68     False
# 75     False
# 183    False
# Name: Recovered, Length: 187, dtype: bool

# %%
df05 = pd.read_csv('Sorted_Confirmed.csv')
df05.columns
# Out:
# Index(['Unnamed: 0', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'New cases', 'New deaths', 'New recovered',
#        'Deaths / 100 Cases', 'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')
